# %% [raw]
# ---
# title: "Prediction Problem"
# subtitle: "STAT 303-3 Spring 25"
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     code-fold: show
#     embed-resources: true
# jupyter: python3
# ---

# %% [markdown]
# ## Instructions:
#
# - Put the parts of your code under the corresponding sections. (0.25/2 points will be taken off for not doing this.)
# - Do not include any redundant/irrelevant code, text or comments. (0.5/2 points will be taken off for not doing this.)
# - **Your code must run without any errors or runtime issues.** (Failure to meet this condition will result in a 0.)
# - **Your code must return your Public Leaderboard score.** (Failure to meet this condition will result in a 0.)

# %% [markdown]
# ## 1) Libraries

# %% [markdown]
# Put all the Python libraries and tools you imported here.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import TunedThresholdClassifierCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# ## 2) Data

# %% [markdown]
# - This section is required to include the code that reads, cleans and preprocesses the datasets.
# - Note that both the training and test datasets should undergo the same sequence of operations.

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
predictors = train.drop(columns = ["host_is_superhost"], axis = 1)
response = train["host_is_superhost"]

# %%
# dropping ID and host_about
# host_location is not useful for prediction because it is the host's area of residence, not necessarily the location of the listing
# latitude and longitude provide redunant information about listing location
# the min/max night columns are not useful since they have very arbitrary, often meaningless values
columns_to_drop = ["id", "host_about", "description", "host_location", "longitude", "latitude", "amenities", "host_verifications", "host_neighbourhood", "property_type", "first_review", "last_review", "bathrooms_text", "has_availability", 'maximum_nights',
       'minimum_minimum_nights', 'maximum_minimum_nights',
       'minimum_maximum_nights', 'maximum_maximum_nights',
       'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm']
initial_cleaned = predictors.drop(columns = columns_to_drop, axis = 1)
test = test.drop(columns = columns_to_drop, axis = 1)

# %%
review_columns = [
    'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
    'review_scores_checkin', 'review_scores_communication', 'review_scores_location',
    'review_scores_value'
]

# fill NaN values in review_columns with median
initial_cleaned[review_columns] = initial_cleaned[review_columns].fillna(initial_cleaned[review_columns].median())
test[review_columns] = test[review_columns].fillna(test[review_columns].median())

# fill NaN values in listing_location with mode
initial_cleaned["listing_location"] = initial_cleaned["listing_location"].fillna(initial_cleaned["listing_location"].mode()[0])
test["listing_location"] = test["listing_location"].fillna(test["listing_location"].mode()[0])

# impute NaN values in host_response_time with mode
initial_cleaned["host_response_time"] = initial_cleaned["host_response_time"].fillna(initial_cleaned["host_response_time"].mode()[0])
test["host_response_time"] = test["host_response_time"].fillna(test["host_response_time"].mode()[0])

# convert host_response_rate and host_acceptance_rate to numeric
initial_cleaned["host_response_rate"] = initial_cleaned["host_response_rate"].str.replace("%", "").astype(float) / 100
initial_cleaned["host_acceptance_rate"] = initial_cleaned["host_acceptance_rate"].str.replace("%", "").astype(float) / 100
test["host_response_rate"] = test["host_response_rate"].str.replace("%", "").astype(float) / 100
test["host_acceptance_rate"] = test["host_acceptance_rate"].str.replace("%", "").astype(float) / 100

# impute NaN values in host_response_rate and host_acceptance_rate with median
initial_cleaned["host_response_rate"] = initial_cleaned["host_response_rate"].fillna(initial_cleaned["host_response_rate"].median())
initial_cleaned["host_acceptance_rate"] = initial_cleaned["host_acceptance_rate"].fillna(initial_cleaned["host_acceptance_rate"].median())
test["host_response_rate"] = test["host_response_rate"].fillna(test["host_response_rate"].median())
test["host_acceptance_rate"] = test["host_acceptance_rate"].fillna(test["host_acceptance_rate"].median())

# impute NaN values in bedrooms and beds with median
initial_cleaned["bedrooms"] = initial_cleaned["bedrooms"].fillna(initial_cleaned["bedrooms"].median())
initial_cleaned["beds"] = initial_cleaned["beds"].fillna(initial_cleaned["beds"].median())
test["bedrooms"] = test["bedrooms"].fillna(test["bedrooms"].median())
test["beds"] = test["beds"].fillna(test["beds"].median())

# impute NaN values in host_listings_count and host_total_listings_count with median
initial_cleaned["host_listings_count"] = initial_cleaned["host_listings_count"].fillna(initial_cleaned["host_listings_count"].median())
initial_cleaned["host_total_listings_count"] = initial_cleaned["host_total_listings_count"].fillna(initial_cleaned["host_total_listings_count"].median())
test["host_listings_count"] = test["host_listings_count"].fillna(test["host_listings_count"].median())
test["host_total_listings_count"] = test["host_total_listings_count"].fillna(test["host_total_listings_count"].median())

# impute NaN values in host_has_profile_pic and host_identity_verified with mode
initial_cleaned["host_has_profile_pic"] = initial_cleaned["host_has_profile_pic"].fillna(initial_cleaned["host_has_profile_pic"].mode()[0])
initial_cleaned["host_identity_verified"] = initial_cleaned["host_identity_verified"].fillna(initial_cleaned["host_identity_verified"].mode()[0])
test["host_has_profile_pic"] = test["host_has_profile_pic"].fillna(test["host_has_profile_pic"].mode()[0])
test["host_identity_verified"] = test["host_identity_verified"].fillna(test["host_identity_verified"].mode()[0])

# impute the NaN value in host_since column with the mode
initial_cleaned["host_since"] = initial_cleaned["host_since"].fillna(initial_cleaned["host_since"].mode()[0])
test["host_since"] = test["host_since"].fillna(test["host_since"].mode()[0])

# impute NaN values in reviews_per_month with median
initial_cleaned["reviews_per_month"] = initial_cleaned["reviews_per_month"].fillna(initial_cleaned["reviews_per_month"].median())
test["reviews_per_month"] = test["reviews_per_month"].fillna(test["reviews_per_month"].median())
# Out:
# /var/folders/j3/xhg265bj3gg399v4cr257t6w0000gn/T/ipykernel_45912/1468992068.py:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   initial_cleaned["host_has_profile_pic"] = initial_cleaned["host_has_profile_pic"].fillna(initial_cleaned["host_has_profile_pic"].mode()[0])
# /var/folders/j3/xhg265bj3gg399v4cr257t6w0000gn/T/ipykernel_45912/1468992068.py:45: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   initial_cleaned["host_identity_verified"] = initial_cleaned["host_identity_verified"].fillna(initial_cleaned["host_identity_verified"].mode()[0])
# /var/folders/j3/xhg265bj3gg399v4cr257t6w0000gn/T/ipykernel_45912/1468992068.py:46: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test["host_has_profile_pic"] = test["host_has_profile_pic"].fillna(test["host_has_profile_pic"].mode()[0])
# /var/folders/j3/xhg265bj3gg399v4cr257t6w0000gn/T/ipykernel_45912/1468992068.py:47: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test["host_identity_verified"] = test["host_identity_verified"].fillna(test["host_identity_verified"].mode()[0])

# %%
# extract year from host_since column, convert to datetime, and drop the original column
initial_cleaned["host_since_year"] = pd.to_datetime(initial_cleaned["host_since"]).dt.year
initial_cleaned.drop(columns=["host_since"], inplace=True)
test["host_since_year"] = pd.to_datetime(test["host_since"]).dt.year
test.drop(columns=["host_since"], inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder

one_hot_encoder = OneHotEncoder(sparse_output=False, drop='first')

# one hot encode host_response_time, listing_location, room_type
one_hot_columns = ["host_response_time", "listing_location", "room_type"]
encoded_one_hot_train = one_hot_encoder.fit_transform(initial_cleaned[one_hot_columns])
encoded_one_hot_df = pd.DataFrame(
    encoded_one_hot_train,
    columns=one_hot_encoder.get_feature_names_out(one_hot_columns),
    index=initial_cleaned.index
)
encoded_one_hot_test = one_hot_encoder.transform(test[one_hot_columns])
encoded_one_hot_test_df = pd.DataFrame(
    encoded_one_hot_test,
    columns=one_hot_encoder.get_feature_names_out(one_hot_columns),
    index=test.index
)

# ordinal encode neighbourhood_cleansed and host_since_year
ordinal_encode_cols = ["neighbourhood_cleansed", "host_since_year"]
ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
ordinal_encoder.fit(initial_cleaned[ordinal_encode_cols])
initial_cleaned[ordinal_encode_cols] = ordinal_encoder.transform(initial_cleaned[ordinal_encode_cols])
test[ordinal_encode_cols] = ordinal_encoder.transform(test[ordinal_encode_cols])


# convert boolean columns to int
bool_columns = [
    "host_has_profile_pic",
    "host_identity_verified",
    "instant_bookable"
]
for col in bool_columns:
    initial_cleaned[col] = initial_cleaned[col].astype(int)
    test[col] = test[col].astype(int)


# concatenate the encoded columns with the original dataframe
cleaned_data_train = pd.concat([initial_cleaned, encoded_one_hot_df], axis=1)
cleaned_data_test = pd.concat([test, encoded_one_hot_test_df], axis=1)

# drop original columns after encoding
cols_to_drop = one_hot_columns
cleaned_data_train.drop(columns=cols_to_drop, inplace=True)
cleaned_data_test.drop(columns=cols_to_drop, inplace=True)

# %%
X_train = cleaned_data_train
y_train = response

# %%
X_test = cleaned_data_test

# %%
from sklearn.ensemble import BaggingClassifier

param_grid = {
    'n_estimators':      [50, 100, 150, 200],
    'max_samples':       [0.5, 0.75, 1.0],
    'max_features':      [0.3, 0.5, 0.75, 1.0],
    'bootstrap':         [True],              
    'bootstrap_features':[True, False],
}

base_model = DecisionTreeClassifier(random_state=42)
bagging_model = BaggingClassifier(
    estimator=base_model,
    oob_score=True,
    random_state=42,
    n_jobs=-1
)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

gscv = GridSearchCV(
    bagging_model,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=cv,
    n_jobs=-1,
    verbose=2,
)

gscv.fit(X_train, y_train)

print("Best params:", gscv.best_params_)
print("Best CV ROC AUC:", gscv.best_score_)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   0.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   2.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   4.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   4.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   3.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   3.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   4.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.3s[CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.4s
#
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   5.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   4.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   4.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   4.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   6.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   6.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   7.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   7.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   7.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   7.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   6.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   6.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   5.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   5.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   5.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   5.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   6.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   7.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   6.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   6.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   6.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   6.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   6.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   6.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   6.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   6.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   9.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   9.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   8.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   8.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  10.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  10.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=0.75, max_samples=1.0, n_estimators=200; total time=   9.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   9.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   8.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   8.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   8.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   9.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   8.6s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   8.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   8.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  11.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  11.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   3.1s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   6.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   6.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   6.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   6.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   6.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=150; total time=   9.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  10.3s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=150; total time=   9.9s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  10.2s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  10.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   1.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  13.5s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  13.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  13.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   2.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=150; total time=   2.7s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  12.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   0.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=True, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  11.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.5, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=150; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   1.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=0.75, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=100; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   4.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=150; total time=   3.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   0.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   1.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   0.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   5.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   4.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.3, max_samples=1.0, n_estimators=200; total time=   5.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   4.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   4.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   4.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   4.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=150; total time=   4.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=50; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   5.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   6.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   5.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   6.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=150; total time=   6.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   7.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   7.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   7.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=50; total time=   1.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   6.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.75, n_estimators=200; total time=   6.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=100; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   6.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   5.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=150; total time=   6.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   8.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   7.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   1.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   7.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=1.0, n_estimators=200; total time=   7.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   6.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   6.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   6.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   6.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=150; total time=   6.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   1.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   7.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   8.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   7.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.5, n_estimators=200; total time=   7.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   7.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   6.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   7.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   7.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=150; total time=   7.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=0.75, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=150; total time=   8.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  11.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  11.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=50; total time=   2.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=0.75, max_samples=1.0, n_estimators=200; total time=  10.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   9.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   9.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.5, n_estimators=200; total time=   9.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   6.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=100; total time=   5.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   9.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   9.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   9.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=150; total time=   9.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=150; total time=  10.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   3.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   3.2s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  12.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  12.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   3.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  12.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   4.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=50; total time=   4.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  13.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=0.75, n_estimators=200; total time=  12.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   8.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   8.3s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   8.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=100; total time=   8.0s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  11.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  11.9s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  11.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  11.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=150; total time=  11.4s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  13.7s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  13.1s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=200; total time=  11.8s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=200; total time=   8.6s
# [CV] END bootstrap=True, bootstrap_features=False, max_features=1.0, max_samples=1.0, n_estimators=200; total time=   7.2s
# Best params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.75, 'max_samples': 1.0, 'n_estimators': 200}
# Best CV ROC AUC: 0.956071404235107

# %% [markdown]
# ## 3) Machine Learning Model

# %% [markdown]
# - This section is required to train the **already tuned** model and obtain the test predictions (or prediction probabilities) with it.
# - As written in the instructions, your code must not have any runtime issues, so **do NOT include your grid search here!** You will still need to tune your model to pass the thresholds. However, you need to keep that as your personal work and should NOT include the grid search here.

# %%
best_model = gscv.best_estimator_
y_test_proba = best_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# ## 4) Exporting the Predictions

# %% [markdown]
# Include the code that (1) puts the predictions in the format that Kaggle understands and (2) exports it as a csv file.

# %%
submission = pd.read_csv('test.csv')
submission = submission[["id"]]
submission["predicted"] = y_test_proba

submission.to_csv('submission.csv', index=False)
